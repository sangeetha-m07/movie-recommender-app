# %% [markdown]
# ### step 1 : load and explore the dataset

# %%
import pandas as pd

# %%
movies = pd.read_csv("tmdb_5000_movies.csv/tmdb_5000_movies.csv")             ## importing the csv file  
credits = pd.read_csv("tmdb_5000_credits.csv/tmdb_5000_credits.csv")

# %%
movies.head()                         ## it shows the first 5 rows of the dataset movies
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head()               ## it shows the first 5 rows of the dataset credits
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %% [markdown]
# ### step 2 : data cleaning and feature selection

# %%
movies = movies.merge(credits, on = "title")           ## here we merged the movies and credits into single dataset

# %%
movies.shape                        ## shape shows how many rows and columns does this dataset contains
# Out:
# (4809, 23)

# %%
movies.head()                       ## it shows the first 5 rows of the dataset
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies = movies[["movie_id", "title", "overview", "genres", "keywords", "cast", "crew"]]   ## keeping the required columns

# %%
## genres : Genres mean the category or type of the movie based on its theme, style, or story
## keywords : Keywords are important words or tags that describe the main themes, topics, or concepts of a movie
## overview : Overview is a short description or summary of what the movie is about — like the plot
## crew : People who work behind the scenes to make the movie, but don’t act in it(director, producer, writer , composer etc...)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
movies.rename(columns = {"id" : "movie_id"}, inplace = True)    ## renaming the id with movie_id(if id is present instead of movie_id)

# %%
movies.isnull().sum()         ## checking for null values
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace = True)              ## droping the null values from the data

# %%
movies.reset_index(drop = True, inplace = True)        ## reindexing after removing the null value(reindex happened because after removing null values index suffled)

# %% [markdown]
# ### step 3 : Data transformation  && step 4 : create tags for each movie

# %%
import ast

# Safer functions to handle bad data
def safe_convert(obj):
    try:
        parsed = ast.literal_eval(obj)
        return [i['name'] for i in parsed]
    except:
        return []

def safe_convert_cast(obj):
    try:
        parsed = ast.literal_eval(obj)
        return [i['name'] for i in parsed[:3]]  # take top 3 cast
    except:
        return []

def safe_fetch_director(obj):
    try:
        parsed = ast.literal_eval(obj)
        for i in parsed:
            if i['job'] == 'Director':
                return [i['name']]  # keep as list
        return []
    except:
        return []

# Apply all conversions
movies['genres'] = movies['genres'].apply(safe_convert)
movies['keywords'] = movies['keywords'].apply(safe_convert)
movies['cast'] = movies['cast'].apply(safe_convert_cast)
movies['crew'] = movies['crew'].apply(safe_fetch_director)
movies['overview'] = movies['overview'].apply(lambda x: x.split() if isinstance(x, str) else [])

# Now create tags properly by concatenating lists
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# Test output
movies[['title', 'tags']].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %% [markdown]
# ### Step 4: Cleaning and Normalizing the Tags.

# %%
# Step 4: Clean and normalize the 'tags' column

# Convert list of words into a single string and lowercase everything
movies['tags'] = movies['tags'].apply(lambda x: " ".join(x))  # join the list
movies['tags'] = movies['tags'].apply(lambda x: x.lower())    # convert to lowercase

# %%
movies[['title', 'tags']].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %% [markdown]
# ### Step 5: Text Vectorization using CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize vectorizer
cv = CountVectorizer(max_features=5000, stop_words='english')

# Transform tags column into vectors
vectors = cv.fit_transform(movies['tags']).toarray()

# %%
vectors.shape
# Out:
# (4806, 5000)

# %% [markdown]
# ### Step 6: Compute Similarity Using Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Create similarity matrix
similarity = cosine_similarity(vectors)

# %%
similarity.shape
# Out:
# (4806, 4806)

# %% [markdown]
# ###  Step 7: Build the Recommendation Function 🎬

# %%
def recommend(movie):
    # Get index of the movie from title
    movie_index = movies[movies['title'] == movie].index[0]
    
    # Get list of (index, similarity_score) for all movies
    distances = list(enumerate(similarity[movie_index]))
    
    # Sort based on similarity score in descending order
    movies_list = sorted(distances, reverse=True, key=lambda x: x[1])[1:6]
    
    # Print recommended movie titles
    for i in movies_list:
        print(movies.iloc[i[0]].title)

# %%
##checking the recommendation

# %%
recommend('Avatar')
# Out:
# Aliens
# Moonraker
# Alien
# Alien³
# Silent Running

# %%
movies['title'].head(20)
# Out:
# 0                                          Avatar
# 1        Pirates of the Caribbean: At World's End
# 2                                         Spectre
# 3                           The Dark Knight Rises
# 4                                     John Carter
# 5                                    Spider-Man 3
# 6                                         Tangled
# 7                         Avengers: Age of Ultron
# 8          Harry Potter and the Half-Blood Prince
# 9              Batman v Superman: Dawn of Justice
# 10                               Superman Returns
# 11                              Quantum of Solace
# 12     Pirates of the Caribbean: Dead Man's Chest
# 13                                The Lone Ranger
# 14                                   Man of Steel
# 15       The Chronicles of Narnia: Prince Caspian
# 16                                   The Avengers
# 17    Pirates of the Caribbean: On Stranger Tides
# 18                                 Men in Black 3
# ...

# %%
recommend("Spectre")
# Out:
# Quantum of Solace
# Never Say Never Again
# From Russia with Love
# Skyfall
# Die Another Day

# %%
recommend("The Dark Knight Rises")
# Out:
# The Dark Knight
# Batman Begins
# Batman
# Batman
# Batman Returns

# %% [markdown]
# ## 🎬 Project Title: Movie Recommendation System
# ## 📌 Brief Description:
# This project recommends movies to users based on a selected movie title. It uses content-based filtering and compares movies using text-based features like genres, keywords, cast, crew, and overview.
#
# We extract and process movie metadata, convert it into numerical form using NLP, calculate similarity scores between movies, and recommend the top 5 similar ones.
# ## Steps You Completed:
# ### 1. Data Loading & Merging
# Loaded two datasets: movies.csv and credits.csv
#
# Merged them on the title column
#
# ### 2. Preprocessing
# Selected relevant columns: movie_id, title, overview, genres, keywords, cast, and crew
#
# Removed null values and duplicates
#
# ### 3. Data Transformation
# Parsed JSON-like strings (genres, cast, etc.) into Python lists using ast.literal_eval
#
# Extracted names (e.g., genre names, top 3 cast members, director)
#
# Created a new column tags combining all key text info
#
# ### 4. Text Cleaning
# Converted tags to lowercase
#
# Joined word lists into strings for each movie
#
# ### 5. Vectorization (NLP)
# Used CountVectorizer to convert text into vectors (top 5000 words)
#
# Removed English stop words
#
# Converted text into numerical matrix
#
# ### 6. Similarity Score Calculation
# Used cosine similarity to compare every movie with every other movie
#
# Created a similarity matrix of shape (4806, 4806)
#
# ### 7. Recommendation Function
# Created a recommend(movie) function that:
#
# Finds the movie
#
# Finds its most similar movies
#
# Prints the top 5 similar movie titles
# ## How It Works:
# When a user inputs a movie name like "Avatar", the system:
#
# Finds its vector in the dataset
#
# Calculates similarity with all other movie vectors
#
# Sorts by similarity score
#
# Recommends the top 5 most similar movies (excluding the movie itself)
